# %%
from logging import root
from tkinter import *
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,
NavigationToolbar2Tk)
from tkinter import simpledialog
import numpy as np
import matplotlib.pyplot as plt

	




ROOT = Tk()

ROOT.withdraw()

# the input dialog
stocks = simpledialog.askstring(title="Test",
                                  prompt="Stocks ticker :")
start = simpledialog.askstring(title="Test",
                                  prompt="start date:")
end = simpledialog.askstring(title="Test",
                                  prompt="end date:")
s = simpledialog.askstring(title="Test",
                                  prompt="open (o) or close (c) stock? :")
	
# %run stocksAPI.ipynb

# %%
y=y_test
pr=predictions

# %%
from tkinter import *
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,
NavigationToolbar2Tk)
from tkinter import simpledialog
import numpy as np
import matplotlib.pyplot as plt

# plot function is created for
# plotting the graph in
# tkinter window

def plot():

	# the figure that will contain the plot
	fig = Figure(figsize = (10, 3),
				dpi = 100)


	# adding the subplot
	plot1 = fig.add_subplot(121)
	plot2 = fig.add_subplot(122)

	# plotting the graph
		
	plot2.plot(pr,color='red',label='predictions')
	plot2.title.set_text('stocks predictions')

	plot1.plot(y,color='blue',label='actual stocks')
	plot1.title.set_text('actual stocks')

	# creating the Tkinter canvas
	# containing the Matplotlib figure
	canvas = FigureCanvasTkAgg(fig,
							master = window)
	canvas.draw()

	# placing the canvas on the Tkinter window
	canvas.get_tk_widget().pack()

	# creating the Matplotlib toolbar
	toolbar = NavigationToolbar2Tk(canvas,
								window)
	toolbar.update()

	# placing the toolbar on the Tkinter window
	canvas.get_tk_widget().pack()

# the main Tkinter window
window = Tk()


# setting the title
window.title('Plotting in Tkinter')

# dimensions of the main window
window.geometry("900x400")

# button that displays the plot
plot_button = Button(master = window,
					command = plot,
					height = 2,
					width = 10,
					text = "Plot")

# place the button
# in main window
plot_button.pack()

# run the gui

window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\PC\Desktop\ML\stocksApi\gui.ipynb Cell 3 in <cell line: 72>()
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/ML/stocksApi/gui.ipynb#W4sZmlsZQ%3D%3D?line=67'>68</a> plot_button.pack()
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/ML/stocksApi/gui.ipynb#W4sZmlsZQ%3D%3D?line=69'>70</a> # run the gui
# ---> <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/ML/stocksApi/gui.ipynb#W4sZmlsZQ%3D%3D?line=71'>72</a> window.mainloop()
#      <a href='vscode-notebook-cell:/c%3A/Users/PC/Desktop/ML/stocksApi/gui.ipynb#W4sZmlsZQ%3D%3D?line=72'>73</a> window.destroy()
#
# File c:\Users\PC\anaconda3\envs\virenv1\lib\tkinter\__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:
